# %% [markdown]
# POC AIS ETL

# %%
config = {}
workingDir = ""
isAirflow = False
isExecuteProductProcessOnly = False
isExecuteEventDataProcessOnly = False
isExecuteRecoveryProcess = False
isExecuteMigrationProcess = False
isExecuteDailySummaryProcess = False
isRetry = False
isMigrationToJson = False
isMigrationToDelta = False

# %% [markdown]
# Set path

# %%
import os
env = os.environ.get("ENVIRONMENT", "dev")
AIRFLOW_HOME = os.environ["AIRFLOW_HOME"] = os.environ.get("AIRFLOW_HOME", "/opt/airflow")
BASE_DIR = f"{AIRFLOW_HOME}/dags"

print(f"AIRFLOW_HOME is set to: {AIRFLOW_HOME}")
print(f"Environment set to: {env}")
# Out:
# AIRFLOW_HOME is set to: /opt/airflow
# Environment set to: dev
# Current working directory: /Users/mac/MyWork/Me/py-data-pipeline/notebooks
# Parent directory is: (BASE_DIR not found in path)

# %%
import os
import sys
working_dir = os.getcwd()
os.chdir("..")
sys.path.append("src")

from app.run import say_hello

say_hello("test")
# Out:
# Hello, test!
# 'Greeting sent to test'

# %%
print("Working directory is: ")
# Out:
# Working directory is:
